# %%
l = [20, 5, 10, 30, 15, 25]
l.append(100)
print(l)
# Out:
# [20, 5, 10, 30, 15, 25, 100]

# %%
l = [20, 5, 10, 30, 15, 25]
l.clear()
print(l)
# Out:
# []

# %%
l = [20, 5, 10, 30, 15, 25]
l.sort()
print(l)
# Out:
# [5, 10, 15, 20, 25, 30]

# %%
l = [20, 5, 10, 30, 15, 25]
l.sort(reverse=True)
print(l)
# Out:
# [30, 25, 20, 15, 10, 5]

# %%
l = [20, 5, 10, 30, 15, 25]
l.sort(reverse=False)
print(l)
# Out:
# [5, 10, 15, 20, 25, 30]

# %%
l = [20, 5, 10, 30, 15, 25]
l.reverse()    # Prints data in reverse order(not sorted)
print(l)
# Out:
# [25, 15, 30, 10, 5, 20]

# %%
l = [20, 5, 10, 30, 15, 25]
l1 = l.copy()
print(l)
print(l1)
# Out:
# [20, 5, 10, 30, 15, 25]
# [20, 5, 10, 30, 15, 25]

# %%
l = [20, 5, 10, 30, 15, 25]
l.insert(2, 90)
print(l)
# Out:
# [20, 5, 90, 10, 30, 15, 25]

# %%
l = [20, 5, 10, 30, 15, 25]
l.remove(30)
print(l)
# Out:
# [20, 5, 10, 15, 25]

# %%
l = [20, 5, 10, 30, 15, 25]
l.pop(2)
print(l)
# Out:
# [20, 5, 30, 15, 25]

# %%
l = [20, 5, 10, 30, 15, 25, 20, 20]
print(l.count(20))
print(l.count(15))
# Out:
# 3
# 1

# %%
l = [20, 5, 10, 30, 15, 25]
print(l.index(20))
print(l.index(10))
# Out:
# 0
# 2

# %%
# Given a list of integers, write a Python program to find and display all positions of a specified element if it occurs multiple times in the list.
l = [20, 5, 10, 30, 15, 25, 20]
for i in range(len(l)):     
    if l[i] == 20:
        print(i)
# Out:
# 0
# 6

# %%
l1 = [20, 5, 10, 30, 15, 25]
l2 = [10, 34, 20, 13, 15]
l1.extend(l2)
print(l1)
# Out:
# [20, 5, 10, 30, 15, 25, 10, 34, 20, 13, 15]
