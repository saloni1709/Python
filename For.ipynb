# %%
pets = ["Cow", "Cat", "Dog"]
for pet in pets:
    print(pets)
# Out:
# ['Cow', 'Cat', 'Dog']
# ['Cow', 'Cat', 'Dog']
# ['Cow', 'Cat', 'Dog']

# %%
pet = ["Cow", "Cat", "Dog"]
for pet in pets:
    print(pet)
# Out:
# Cow
# Cat
# Dog

# %%
txt = "Hello"
for x in txt:
    print(x)
# Out:
# H
# e
# l
# l
# o

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for x in range(1,5):
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in range(2, 11, 2):
    print(x)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for x in range(5,-1,-1):
    print(x)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
sum = 0
n = 5
for x in range(1,n-1):
    sum+=n
print(sum)
# Out:
# 15

# %%
for i in range(1, 11):
    print("4*", i, "=", 4*i)
# Out:
# 4* 1 = 4
# 4* 2 = 8
# 4* 3 = 12
# 4* 4 = 16
# 4* 5 = 20
# 4* 6 = 24
# 4* 7 = 28
# 4* 8 = 32
# 4* 9 = 36
# 4* 10 = 40

# %%
n = 7
for i in range(2, n):
    if n%i==0:
        print("Not Prime")
        break
else:
    print("Prime")
# Out:
# Prime

# %%
n = 1234
sum = 0
while n!=0:
    rem = n%10
    sum+=rem
    n//=10
print(sum)
# Out:
# 10

# %%
n = 11
for i in range(1, n):
    if i%3==0 or i%5==0:
        print(i)
# Out:
# 3
# 5
# 6
# 9
# 10

# %%
# find all the factors of given no
# factor -> Jo numbers n ko completely divide kar dein (remainder 0 aaye)

x = 20
for i in range(1, x+1):
    if x%i==0:
        print(i)
# Out:
# 1
# 2
# 4
# 5
# 10
# 20

# %%
x = 22/7
print('value of pi: %.3f' %(x))
# Out:
# value of pi: 3.143

# %%
x = 22/7
print('value of pi = {0:.2f}' .format(x))
# Out:
# value of pi = 3.14

# %%
x = 22/7
print(f'value of pi : {x:.3f}')
# Out:
# value of pi : 3.143

# %%
print("Welcome to", end=' ')
print("Python", end=' ')
# Out:
# Welcome to Python

# %%
print("Stack", end=' @ ')
print("home")
# Out:
# Stack @ home

# %%
print('G', 'F', 'E', sep=' @ ')
# Out:
# G @ F @ E

# %%
print('17', '09', '2005', sep=' - ')
# Out:
# 17 - 09 - 2005

# %%
animal = ["Tiger", "Cat"]
sound = ["Roare", "Meow"]
for x in animal:
    for y in sound:
        print(f"the {x} {y}")
# Out:
# the Tiger Roare
# the Tiger Meow
# the Cat Roare
# the Cat Meow

# %%
n = 15
for i in range(2, n):
    if n%i==0:
        print("n")
        break
else:
    print("p")
# Out:
# n

# %%
# find all the prime no less than the entered no. 
n = 15  
for num in range(2, n):
    for x in range(2, num):
        if(num%x==0):
            break
    else:
        print(num)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
