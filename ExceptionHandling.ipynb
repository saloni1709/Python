# %%
amount = 30000
if amount >2999     # Syntax Error
   print("You are eligible for gift")
# Out:
#   Cell In[1], line 2
#     if amount >2999
#                    ^
# SyntaxError: expected ':'

# %%
a = [1,2,3]
try:
    print("Second Element=", a[1])
    # throws an error since there are only 3 elements in list
    print("Fourth Element=", a[3])

except IndexError:
       print("An Error Occured")
# Out:
# Second Element= 2
# An Error Occured

# %%
# Python program to handle multiple errors with one except statement

try:
    a = 3
    if a < 4:
        b = a / (a - 3)   # ZeroDivisionError
    print("Value of b =", b)

except (ZeroDivisionError, NameError):
    print("Error Occurred & Handled")
# Out:
# Error Occurred & Handled

# %%
try:
    k = 5 // 0        # This will raise ZeroDivisionError
    print(k)

except ZeroDivisionError:
    print("Can't divide by zero")

finally:
    # This block is always executed
    # regardless of whether an exception occurs or not
    print("This is always executed")
# Out:
# Can't divide by zero
# This is always executed

# %%
try: 
    raise NameError("Hi there")   # Raise Error
except NameError:
     print('An exception')
     raise   # to determine whether exception was raised or not
# Out:
# An exception
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 try:
# ----> 2     raise NameError("Hi there")   # Raise Error
#       3 except NameError:
#       4      print('An exception')
#
# NameError: Hi there

# %%
.
