# %%
tup = (1,4,7,2)
print(tup.index(2))
print(tup.index(7))
# Out:
# 3
# 2

# %%
t = ('a', 'b', 'c', 'd')
print(t[0])
# Out:
# a

# %%
tup = (1,2,4,2,7,2,2)
print(tup.count(2))
# Out:
# 4

# %%
tup = (1,4,7,2)
print(type(tup))
# Out:
# <class 'tuple'>

# %%
t1 = ('a',)
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1 = ('a')
print(type(t1))
# Out:
# <class 'str'>

# %%
t = tuple("hello")   # "hello" string ke har character ko tuple ke ek element me convert kar deta hai
print(t)             # tuple ko print karta hai
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
# Slicing

t = (1,2,3,4)
print(t[1:3])
# Out:
# (2, 3)

# %%
my_tuple = (1,4,[2,6])
print(my_tuple)
# Out:
# (1, 4, [2, 6])

# %%
my_tuple = (1,4,[2,6])
my_tuple[2][0] = 9
print(my_tuple)
# Out:
# (1, 4, [9, 6])

# %%
t1 = (1,2,3)
t2 = (4,5,6)
print(t1+t2)
print(t1*3)
# Out:
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
print((1,2)*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t = ('a', 'p', 'p', 'l', 'e')
print(t.count('p'))
print(t.count('a'))
print(t.index('l'))
print(t.index('p'))
# Out:
# 2
# 1
# 3
# 1
