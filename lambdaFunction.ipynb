# %% [markdown]
# Lambda function ek small, anonymous (naam ke bina) function hota hai
# Sirf one-line expression ke liye use hota hai
# Functional programming ka important part hai

# %%
cube = lambda x: x*x*x
print(cube(7))
# Out:
# 343

# %%
add = lambda x,y: x+y
print(add(2,3))
# Out:
# 5
