# %%
Orinum = 12321
num = Orinum
rev = 0
while num>0:
    digit = num%10
    rev = rev*10+digit
    num = num//10
if Orinum == rev:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
num = 1234
rev = 0
while num>0:
    digit = num%10
    rev = rev*10+digit
    num//=10
print(rev)
# Out:
# 4321

# %%
num = 12345
sum = 0
while num > 0:
    digit = num%10
    sum = sum+digit
    num//=10
print(sum)
# Out:
# 15

# %%
n = 4
fact = 1
for i in range(1, n+1):
    fact*=i
    print(fact)
    i+=1
# Out:
# 1
# 2
# 6
# 24

# %%
n = 4
if n%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
n = 25
for i in range(2, n):
    if(n%i==0):
        print("Not Prime")
        break
else:
    print("Prime")
# Out:
# Not Prime
